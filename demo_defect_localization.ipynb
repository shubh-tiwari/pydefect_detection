# %%
from defect_localize import *

# %%
#Reading the image contain the ROI
img = cv2.imread(r"C:\Users\shubh\Desktop\surface_defect_image\input\image1.jpg", 1)
plt.imshow(img, cmap='gray')
plt.show()

# %%
#Performing histogram equalizaion for contra
hist_eq_img = hist_eq(img)
plt.imshow(hist_eq_img, cmap='gray')
plt.show()

# %%
clahe_eq_img = clah_eq(img)
plt.imshow(clahe_eq_img, cmap='gray')
plt.show()

# %%
defect_img = extract_decoloration(img)
plt.imshow(defect_img, cmap='gray')
plt.show()
